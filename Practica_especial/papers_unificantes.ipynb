#  '4bce2bfd-049d-4980-8bb3-090c2b57c8bc',
#  '5730a8b5-1369-4073-bb15-a1319c167497',
#  '4ef15248-38df-42be-b3d1-43462be6ca64',
#  '2e4b6a1f-4418-4768-91ba-d01956821abb',
#  '4e8b96db-2b84-42e2-8977-ec495b4ebca2',
#  '2d485b8c-c928-41ce-bbf1-d6516d442371']

# %%
import numpy as np
import ast
import networkx as nx
import matplotlib.pyplot as plt
from collections import Counter

directorio='G:\\Redes\\'
version=5

# %%
titulos=[]
archivo = open(directorio+'papers_filtrados'+str(version)+'.txt','r',encoding='utf-8')
for line in archivo:
    paper=ast.literal_eval(line)
    if paper['id'] in papers_unif:
        titulos.append(paper)
        print(titulos)
archivo.close()
# Out:
# [{'title': 'Radiation and reception with buried and submerged antennas', 'n_citation': 64, 'year': 1963, 'authors': [{'name': 'R. C. Hansen', 'org': 'Aerospace Corporation, Los Angeles, CA, USA'}], 'references': ['021b5364-92b4-45fa-b604-88a1599e49ce', '0d749ed3-a230-411a-b217-b795e6dd35bb', '1133161d-0c23-47bf-9179-996868b30e82', '1173397b-9ced-4eb7-b930-0894aad6d047', '1645b27e-6e82-4408-ba37-693c4f8eb887', '16ef420e-e437-41ac-b828-47ea1feddb54', '17853c28-8954-4356-b7ba-de6417df228f', '1cc623f0-c137-4505-b776-4ba8315f1c01', '1f385b65-b3b2-4788-b187-1be6ed32ec16', '24deedb4-71ad-483b-b622-fbda608c14e0', '25da7433-b753-4c01-8808-23799e383a2b', '263867a6-9c09-48ab-95b6-77c532e2689a', '2d734bd0-e3b8-48ef-9358-44fa3936390f', '3a31771c-679e-4c8f-855b-fd4a6f87369a', '3c46f1df-cea6-4f05-97f9-79eedbe2d018', '3eda5876-dc73-4713-b0e1-67ce11ab8bf7', '468813e9-3d01-4930-be83-1293f4842a80', '4992fa6f-9124-47ad-9fd1-86e57fcefdef', '50f7e52c-301e-4f09-8b0e-bea4a1ac52f9', '527d44b1-7fb6-4fd9-9cf5-
# ...

# %%
titulos
# Out:
# [{'title': 'Radiation and reception with buried and submerged antennas',
#   'n_citation': 64,
#   'year': 1963,
#   'authors': [{'name': 'R. C. Hansen',
#     'org': 'Aerospace Corporation, Los Angeles, CA, USA'}],
#   'references': ['021b5364-92b4-45fa-b604-88a1599e49ce',
#    '0d749ed3-a230-411a-b217-b795e6dd35bb',
#    '1133161d-0c23-47bf-9179-996868b30e82',
#    '1173397b-9ced-4eb7-b930-0894aad6d047',
#    '1645b27e-6e82-4408-ba37-693c4f8eb887',
#    '16ef420e-e437-41ac-b828-47ea1feddb54',
#    '17853c28-8954-4356-b7ba-de6417df228f',
#    '1cc623f0-c137-4505-b776-4ba8315f1c01',
#    '1f385b65-b3b2-4788-b187-1be6ed32ec16',
#    '24deedb4-71ad-483b-b622-fbda608c14e0',
#    '25da7433-b753-4c01-8808-23799e383a2b',
#    '263867a6-9c09-48ab-95b6-77c532e2689a',
#    '2d734bd0-e3b8-48ef-9358-44fa3936390f',
#    '3a31771c-679e-4c8f-855b-fd4a6f87369a',
#    '3c46f1df-cea6-4f05-97f9-79eedbe2d018',
#    '3eda5876-dc73-4713-b0e1-67ce11ab8bf7',
#    '468813e9-3d01-4930-be83-1293f4842a80',
# ...
