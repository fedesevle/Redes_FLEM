# %%
import matplotlib.pylab as plt
import networkx as nx
import numpy as np
import pandas as pd

G = nx.read_gml("dolphins.gml")

def ldata(archive):
    f=open(archive)
    data=[]
    for line in f:
        line=line.strip()
        col=line.split()
        data.append(col)
    return data

a = ldata("dolphinsGender.txt")
#print(a)

nx.draw(G, node_size=10)
plt.show()

options = {
     'node_color': 'red',
     'node_size': 30,
     'width': 3,
}
plt.subplot(221)
nx.draw_random(G, **options)
plt.subplot(222)
nx.draw_circular(G, **options)
plt.subplot(223)
nx.draw_spectral(G, **options)
#plt.subplot(224)
#nx.draw_shell(G, nlist=[range(5,10), range(5)], **options)

#grados_2 = [gra for (nom,gra) in G.degree()]

#print(a[1])
Agen=[]
Anom=[]
for (nom,gen) in a
    G.add_nodes_from(Agen.append(nom), gender='female')

nx.draw(G, 
        width=5, 
        node_color=["blue" if g=="female" else "red" for g in nx.get_node_attributes(G, "gender").values()], 
        node_size=400,
        with_labels=True
       )


#plt.show()
# Out:
# ['Cross', 'm']

# %%
G.number_of_nodes()
# Out:
# 62

# %%
H = nx.Graph()#directed

H.add_edges_from([(1, 2), (2, 3), (3, 1)])

H.add_nodes_from([1], gender='female')
H.add_nodes_from([4], gender='male')
H.add_nodes_from([3], gender='male')

nx.draw(H, 
        width=5, 
        node_color=["blue" if g=="female" else "red" for g in nx.get_node_attributes(H, "gender").values()], 
        node_size=400,
        with_labels=True
       )

plt.show()
